# %% [markdown]
# # Random Forest Regression for Car Price Prediction
#
# ![aicared.jpg](attachment:e4565b2d-bab2-4322-9fb1-6e2fa21c199d.jpg)
#
# Valuing a car based on its features at any one time is tricky and often researched on an individual basis or referred to 3rd party valuations. Appropriate pricing is a challenged faced by both dealers and consumers.
#
# In this project I undertake machine learning in Python using Random Forest Regression model on public car sales data to understand the process, data restriction and check the viability of machine learning for the prediction of car sales price.
#
# The best result for this project is an accuracy of 80% with the average price error of £794.85.

# %% [markdown]
# Data was collected from Kaggle, with the original data source of Autotrader.co.uk. It contains 3,685 data points and thirteen distinct features, collected in October 2023.

# %% [markdown]
# ## Importing and examining data

# %%
#import and load planned packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

# %%
#load and read data

data = pd.read_csv('used_cars_UK-c2.xls')
pd.set_option('display.max_columns', 25)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3685 entries, 0 to 3684
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3685 non-null   int64
#  1   title              3685 non-null   object
#  2   Price              3685 non-null   int64
#  3   Mileage(miles)     3685 non-null   int64
#  4   Registration_Year  3685 non-null   int64
#  5   Previous Owners    2276 non-null   float64
#  6   Fuel type          3685 non-null   object
#  7   Body type          3685 non-null   object
#  8   Engine             3640 non-null   object
#  9   Gearbox            3685 non-null   object
#  10  Doors              3660 non-null   float64
#  11  Seats              3650 non-null   float64
#  12  Emission Class     3598 non-null   object
#  13  Service history    540 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 403.2+ KB

# %%
data.head()
# Out:
#    Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0           0     SKODA Fabia   6900           70189               2016
# 1           1  Vauxhall Corsa   1495           88585               2008
# 2           2     Hyundai i30    949          137000               2011
# 3           3      MINI Hatch   2395           96731               2010
# 4           4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class Service history
# 0         Euro 6             NaN
# 1         Euro 4            Full
# 2         Euro 5             NaN
# 3         Euro 4            Full
# 4         Euro 5             NaN

# %%
data.describe()
# Out:
#         Unnamed: 0         Price  Mileage(miles)  Registration_Year  \
# count  3685.000000   3685.000000    3.685000e+03        3685.000000
# mean   2314.770963   5787.145726    8.132816e+04        2011.835007
# std    1415.821308   4480.810572    3.942083e+04           5.092566
# min       0.000000    400.000000    1.000000e+00        1953.000000
# 25%    1059.000000   2490.000000    5.698400e+04        2008.000000
# 50%    2279.000000   4000.000000    8.000000e+04        2012.000000
# 75%    3593.000000   7995.000000    1.030000e+05        2015.000000
# max    4727.000000  33900.000000    1.110100e+06        2023.000000
#
#        Previous Owners        Doors        Seats
# count      2276.000000  3660.000000  3650.000000
# mean          2.807557     4.321038     4.900274
# std           1.546028     0.986902     0.577200
# min           1.000000     2.000000     2.000000
# 25%           2.000000     3.000000     5.000000
# 50%           3.000000     5.000000     5.000000
# 75%           4.000000     5.000000     5.000000
# max           9.000000     5.000000     7.000000

# %% [markdown]
# ### Changing column headers

# %%
# column headers remove spaces and transform to lowercase 
data.columns = data.columns.str.replace(' ', '_')
data.columns = map(str.lower, data.columns)
data.head()
# Out:
#    unnamed:_0           title  price  mileage(miles)  registration_year  \
# 0           0     SKODA Fabia   6900           70189               2016
# 1           1  Vauxhall Corsa   1495           88585               2008
# 2           2     Hyundai i30    949          137000               2011
# 3           3      MINI Hatch   2395           96731               2010
# 4           4  Vauxhall Corsa   1000           85000               2013
#
#    previous_owners fuel_type  body_type engine gearbox  doors  seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   emission_class service_history
# 0         Euro 6             NaN
# 1         Euro 4            Full
# 2         Euro 5             NaN
# 3         Euro 4            Full
# 4         Euro 5             NaN

# %% [markdown]
# ### Adding car age

# %%
# Add car age based on registraition year 
import datetime
date = datetime.date.today()
data['age'] = datetime.datetime.now().year - data['registration_year']

data.head()
# Out:
#    unnamed:_0           title  price  mileage(miles)  registration_year  \
# 0           0     SKODA Fabia   6900           70189               2016
# 1           1  Vauxhall Corsa   1495           88585               2008
# 2           2     Hyundai i30    949          137000               2011
# 3           3      MINI Hatch   2395           96731               2010
# 4           4  Vauxhall Corsa   1000           85000               2013
#
#    previous_owners fuel_type  body_type engine gearbox  doors  seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   emission_class service_history  age
# 0         Euro 6             NaN    8
# 1         Euro 4            Full   16
# 2         Euro 5             NaN   13
# 3         Euro 4            Full   14
# 4         Euro 5             NaN   11

# %% [markdown]
# ## Data cleansing and transformation
#
# - Removing string data.
# - Changing data type to numeric.
# - Separating 'title' string and keeping 'make'.
# - One-hot encoding 'make'.
# - Dropping unused columns.
# - Replacing missing values with mean.
# - Splitting test and train data.

# %%
#cleansing & transformation

#remove 'L' engine#
data["engine"] = [str(x).replace('L','') for x in data["engine"]]
data["engine"] = [str(x).replace('nan','') for x in data["engine"]]
data["engine"] = pd.to_numeric(data["engine"])

#remove 'Euro' emission
data["emission_class"] = [str(x).replace('Euro ','') for x in data["emission_class"]]
data["emission_class"] = [str(x).replace('nan','') for x in data["emission_class"]]
data["emission_class"] = pd.to_numeric(data["emission_class"])

# %%
#seperate car make and model 
#new data frame with split value columns
new = data["title"].str.split(" ", n=1, expand=True)

#making separate first name column from new data frame
data["make"] = new[0]
data.head()
# Out:
#    unnamed:_0           title  price  mileage(miles)  registration_year  \
# 0           0     SKODA Fabia   6900           70189               2016
# 1           1  Vauxhall Corsa   1495           88585               2008
# 2           2     Hyundai i30    949          137000               2011
# 3           3      MINI Hatch   2395           96731               2010
# 4           4  Vauxhall Corsa   1000           85000               2013
#
#    previous_owners fuel_type  body_type  engine gearbox  doors  seats  \
# 0              3.0    Diesel  Hatchback     1.4  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback     1.2  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback     1.4  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback     1.4  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback     1.3  Manual    5.0    5.0
#
#    emission_class service_history  age      make
# 0             6.0             NaN    8     SKODA
# 1             4.0            Full   16  Vauxhall
# 2             5.0             NaN   13   Hyundai
# 3             4.0            Full   14      MINI
# 4             5.0             NaN   11  Vauxhall

# %%
# One-Hot Encoding for new 'make' column
df_enc = pd.get_dummies(data, columns=['make'])
df_enc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3685 entries, 0 to 3684
# Data columns (total 63 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   unnamed:_0          3685 non-null   int64
#  1   title               3685 non-null   object
#  2   price               3685 non-null   int64
#  3   mileage(miles)      3685 non-null   int64
#  4   registration_year   3685 non-null   int64
#  5   previous_owners     2276 non-null   float64
#  6   fuel_type           3685 non-null   object
#  7   body_type           3685 non-null   object
#  8   engine              3640 non-null   float64
#  9   gearbox             3685 non-null   object
#  10  doors               3660 non-null   float64
#  11  seats               3650 non-null   float64
#  12  emission_class      3598 non-null   float64
#  13  service_history     540 non-null    object
#  14  age                 3685 non-null   int64
#  15  make_Abarth         3685 non-null   bool
#  16  make_Alfa           3685 non-null   bool
#  17  make_Audi           3685 non-null   bool
#  18  make_BMW            3685 non-null   bool
#  19  make_Chevrolet      3685 non-null   bool
#  20  make_Chrysler       3685 non-null   bool
#  21  make_Citroen        3685 non-null   bool
#  22  make_DS             3685 non-null   bool
#  23  make_Dacia          3685 non-null   bool
#  24  make_Daewoo         3685 non-null   bool
#  25  make_Daihatsu       3685 non-null   bool
#  26  make_Dodge          3685 non-null   bool
#  27  make_Fiat           3685 non-null   bool
#  28  make_Ford           3685 non-null   bool
#  29  make_Honda          3685 non-null   bool
#  30  make_Hyundai        3685 non-null   bool
#  31  make_Infiniti       3685 non-null   bool
#  32  make_Isuzu          3685 non-null   bool
#  33  make_Jaguar         3685 non-null   bool
#  34  make_Jeep           3685 non-null   bool
#  35  make_KIA            3685 non-null   bool
#  36  make_Lagonda        3685 non-null   bool
#  37  make_Land           3685 non-null   bool
#  38  make_Lexus          3685 non-null   bool
#  39  make_MG             3685 non-null   bool
#  40  make_MINI           3685 non-null   bool
#  41  make_Marcos         3685 non-null   bool
#  42  make_Maserati       3685 non-null   bool
#  43  make_Mazda          3685 non-null   bool
#  44  make_Mercedes-Benz  3685 non-null   bool
#  45  make_Mitsubishi     3685 non-null   bool
#  46  make_Nissan         3685 non-null   bool
#  47  make_Peugeot        3685 non-null   bool
#  48  make_Porsche        3685 non-null   bool
#  49  make_Proton         3685 non-null   bool
#  50  make_Renault        3685 non-null   bool
#  51  make_Rover          3685 non-null   bool
#  52  make_SEAT           3685 non-null   bool
#  53  make_SKODA          3685 non-null   bool
#  54  make_Saab           3685 non-null   bool
#  55  make_Smart          3685 non-null   bool
#  56  make_Ssangyong      3685 non-null   bool
#  57  make_Subaru         3685 non-null   bool
#  58  make_Suzuki         3685 non-null   bool
#  59  make_Toyota         3685 non-null   bool
#  60  make_Vauxhall       3685 non-null   bool
#  61  make_Volkswagen     3685 non-null   bool
#  62  make_Volvo          3685 non-null   bool
# dtypes: bool(48), float64(5), int64(5), object(5)
# memory usage: 604.7+ KB

# %%
#check correlation plot#
data_corr = data[[ 'mileage(miles)', 'age', 'previous_owners', 'engine', 'emission_class', 'doors', 'seats', 'price']]
cc = sns.heatmap(data_corr.corr(), annot=True)

# %%
#check price distribution
fig=plt.figure(figsize=(8,4))
sns.histplot(data_corr['price'])
plt.title('price distribution')
# Out:
# D:\Users\ecasw\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'price distribution')

# %%
#drop unused variables#
data_c = df_enc.drop(columns=['unnamed:_0', 'title', 'registration_year', 'fuel_type', 'body_type', 'gearbox', 'service_history'])
data_c.head()
# Out:
#    price  mileage(miles)  previous_owners  engine  doors  seats  \
# 0   6900           70189              3.0     1.4    5.0    5.0
# 1   1495           88585              4.0     1.2    3.0    5.0
# 2    949          137000              NaN     1.4    5.0    5.0
# 3   2395           96731              5.0     1.4    3.0    4.0
# 4   1000           85000              NaN     1.3    5.0    5.0
#
#    emission_class  age  make_Abarth  make_Alfa  make_Audi  make_BMW  ...  \
# 0             6.0    8        False      False      False     False  ...
# 1             4.0   16        False      False      False     False  ...
# 2             5.0   13        False      False      False     False  ...
# 3             4.0   14        False      False      False     False  ...
# 4             5.0   11        False      False      False     False  ...
#
#    make_Rover  make_SEAT  make_SKODA  make_Saab  make_Smart  make_Ssangyong  \
# 0       False      False        True      False       False           False
# 1       False      False       False      False       False           False
# 2       False      False       False      False       False           False
# 3       False      False       False      False       False           False
# 4       False      False       False      False       False           False
#
#    make_Subaru  make_Suzuki  make_Toyota  make_Vauxhall  make_Volkswagen  \
# 0        False        False        False          False            False
# 1        False        False        False           True            False
# 2        False        False        False          False            False
# 3        False        False        False          False            False
# 4        False        False        False           True            False
#
#    make_Volvo
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#
# [5 rows x 56 columns]

# %%
#deal with missing values
#replace NaN values with mean
data_c['doors'] = data_c['doors'].fillna(data_c['doors'].mean())
data_c['emission_class'] = data_c['emission_class'].fillna(data_c['emission_class'].mean())
data_c['engine'] = data_c['engine'].fillna(data_c['emission_class'].mean())
data_c['seats'] = data_c['seats'].fillna(data_c['seats'].mean())
data_c['previous_owners'] = data_c['previous_owners'].fillna(data_c['previous_owners'].mean())
data_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3685 entries, 0 to 3684
# Data columns (total 56 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   price               3685 non-null   int64
#  1   mileage(miles)      3685 non-null   int64
#  2   previous_owners     3685 non-null   float64
#  3   engine              3685 non-null   float64
#  4   doors               3685 non-null   float64
#  5   seats               3685 non-null   float64
#  6   emission_class      3685 non-null   float64
#  7   age                 3685 non-null   int64
#  8   make_Abarth         3685 non-null   bool
#  9   make_Alfa           3685 non-null   bool
#  10  make_Audi           3685 non-null   bool
#  11  make_BMW            3685 non-null   bool
#  12  make_Chevrolet      3685 non-null   bool
#  13  make_Chrysler       3685 non-null   bool
#  14  make_Citroen        3685 non-null   bool
#  15  make_DS             3685 non-null   bool
#  16  make_Dacia          3685 non-null   bool
#  17  make_Daewoo         3685 non-null   bool
#  18  make_Daihatsu       3685 non-null   bool
#  19  make_Dodge          3685 non-null   bool
#  20  make_Fiat           3685 non-null   bool
#  21  make_Ford           3685 non-null   bool
#  22  make_Honda          3685 non-null   bool
#  23  make_Hyundai        3685 non-null   bool
#  24  make_Infiniti       3685 non-null   bool
#  25  make_Isuzu          3685 non-null   bool
#  26  make_Jaguar         3685 non-null   bool
#  27  make_Jeep           3685 non-null   bool
#  28  make_KIA            3685 non-null   bool
#  29  make_Lagonda        3685 non-null   bool
#  30  make_Land           3685 non-null   bool
#  31  make_Lexus          3685 non-null   bool
#  32  make_MG             3685 non-null   bool
#  33  make_MINI           3685 non-null   bool
#  34  make_Marcos         3685 non-null   bool
#  35  make_Maserati       3685 non-null   bool
#  36  make_Mazda          3685 non-null   bool
#  37  make_Mercedes-Benz  3685 non-null   bool
#  38  make_Mitsubishi     3685 non-null   bool
#  39  make_Nissan         3685 non-null   bool
#  40  make_Peugeot        3685 non-null   bool
#  41  make_Porsche        3685 non-null   bool
#  42  make_Proton         3685 non-null   bool
#  43  make_Renault        3685 non-null   bool
#  44  make_Rover          3685 non-null   bool
#  45  make_SEAT           3685 non-null   bool
#  46  make_SKODA          3685 non-null   bool
#  47  make_Saab           3685 non-null   bool
#  48  make_Smart          3685 non-null   bool
#  49  make_Ssangyong      3685 non-null   bool
#  50  make_Subaru         3685 non-null   bool
#  51  make_Suzuki         3685 non-null   bool
#  52  make_Toyota         3685 non-null   bool
#  53  make_Vauxhall       3685 non-null   bool
#  54  make_Volkswagen     3685 non-null   bool
#  55  make_Volvo          3685 non-null   bool
# dtypes: bool(48), float64(5), int64(3)
# memory usage: 403.2 KB

# %%
# split the data into features (X) and target (price)
X = data_c.drop('price', axis=1)
y = data_c['price']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2763 entries, 1730 to 2223
# Data columns (total 55 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mileage(miles)      2763 non-null   int64
#  1   previous_owners     2763 non-null   float64
#  2   engine              2763 non-null   float64
#  3   doors               2763 non-null   float64
#  4   seats               2763 non-null   float64
#  5   emission_class      2763 non-null   float64
#  6   age                 2763 non-null   int64
#  7   make_Abarth         2763 non-null   bool
#  8   make_Alfa           2763 non-null   bool
#  9   make_Audi           2763 non-null   bool
#  10  make_BMW            2763 non-null   bool
#  11  make_Chevrolet      2763 non-null   bool
#  12  make_Chrysler       2763 non-null   bool
#  13  make_Citroen        2763 non-null   bool
#  14  make_DS             2763 non-null   bool
#  15  make_Dacia          2763 non-null   bool
#  16  make_Daewoo         2763 non-null   bool
#  17  make_Daihatsu       2763 non-null   bool
#  18  make_Dodge          2763 non-null   bool
#  19  make_Fiat           2763 non-null   bool
#  20  make_Ford           2763 non-null   bool
#  21  make_Honda          2763 non-null   bool
#  22  make_Hyundai        2763 non-null   bool
#  23  make_Infiniti       2763 non-null   bool
#  24  make_Isuzu          2763 non-null   bool
#  25  make_Jaguar         2763 non-null   bool
#  26  make_Jeep           2763 non-null   bool
#  27  make_KIA            2763 non-null   bool
#  28  make_Lagonda        2763 non-null   bool
#  29  make_Land           2763 non-null   bool
#  30  make_Lexus          2763 non-null   bool
#  31  make_MG             2763 non-null   bool
#  32  make_MINI           2763 non-null   bool
#  33  make_Marcos         2763 non-null   bool
#  34  make_Maserati       2763 non-null   bool
#  35  make_Mazda          2763 non-null   bool
#  36  make_Mercedes-Benz  2763 non-null   bool
#  37  make_Mitsubishi     2763 non-null   bool
#  38  make_Nissan         2763 non-null   bool
#  39  make_Peugeot        2763 non-null   bool
#  40  make_Porsche        2763 non-null   bool
#  41  make_Proton         2763 non-null   bool
#  42  make_Renault        2763 non-null   bool
#  43  make_Rover          2763 non-null   bool
#  44  make_SEAT           2763 non-null   bool
#  45  make_SKODA          2763 non-null   bool
#  46  make_Saab           2763 non-null   bool
#  47  make_Smart          2763 non-null   bool
#  48  make_Ssangyong      2763 non-null   bool
#  49  make_Subaru         2763 non-null   bool
#  50  make_Suzuki         2763 non-null   bool
#  51  make_Toyota         2763 non-null   bool
#  52  make_Vauxhall       2763 non-null   bool
#  53  make_Volkswagen     2763 non-null   bool
#  54  make_Volvo          2763 non-null   bool
# dtypes: bool(48), float64(5), int64(2)
# memory usage: 302.2 KB

# %% [markdown]
# ## Random Forest regression model evaluation

# %%
#Run random forest regression , evaluate default

def evaluate(model, X_test, y_test):
    predictions = model.predict(X_test)
    errors = abs(predictions - y_test)
    mape = 100 * np.mean(errors / y_test)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f}.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
rf_acc = evaluate(rf, X_test, y_test)
# Out:
# Model Performance
# Average Error: 841.9871.
# Accuracy = 79.77%.

# %%
#Visualise trees
for i in range(3):
    tree = rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=2, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %% [markdown]
# ## Hyperparameter tuning with RandomizedSearchCV

# %%
from pprint import pprint
from sklearn.model_selection import RandomizedSearchCV
#number of trees in rf
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
#number of features to consider
max_features = ['auto', 'sqrt']
#maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(8, 110, num = 11)]
max_depth.append(None)
#minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
#minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
#method of selecting samples for training each tree
bootstrap = [True, False]
#create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
pprint(random_grid)
# Out:
# {'bootstrap': [True, False],
#  'max_depth': [8, 18, 28, 38, 48, 59, 69, 79, 89, 99, 110, None],
#  'max_features': ['auto', 'sqrt'],
#  'min_samples_leaf': [1, 2, 4],
#  'min_samples_split': [2, 5, 10],
#  'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000]}

# %%
rf = RandomForestRegressor()
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently in use:\n')
pprint(rf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
#use the random grid to search for best hyperparameters, create the base model to tune
rf = RandomForestRegressor()
#random search of parameters, 3 fold cross validation, 
#search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, scoring='neg_mean_absolute_error', cv = 3, verbose=2, random_state=42, n_jobs = -1)
#fit the random search model
rf_random.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestRegressor(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [8, 18, 28, 38, 48, 59, 69,
#                                                       79, 89, 99, 110, None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    random_state=42, scoring='neg_mean_absolute_error',
#                    verbose=2)

# %% [markdown]
# ## Evaluate best parameter model

# %%
#show best parameters from randomizedsearchcv
(rf_random.best_params_)
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': None,
#  'bootstrap': False}

# %%
#evaluate and fit base model
def evaluate(model, X_test, y_test):
    predictions = model.predict(X_test)
    errors = abs(predictions - y_test)
    mape = 100 * np.mean(errors / y_test)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f}.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy
base_model = RandomForestRegressor()
base_model.fit(X_train, y_train)
base_accuracy = evaluate(base_model, X_test, y_test)
# Out:
# Model Performance
# Average Error: 847.7745.
# Accuracy = 79.89%.

# %%
#evaluate vest random 
best_random = rf_random.best_estimator_
best_random.fit(X_train, y_train)
random_accuracy = evaluate(best_random, X_test, y_test)
# Out:
# Model Performance
# Average Error: 794.8542.
# Accuracy = 80.10%.

# %%
#Visualise tree tops of best_random
for i in range(5):
    tree = rf_random.best_estimator_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=2, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)
